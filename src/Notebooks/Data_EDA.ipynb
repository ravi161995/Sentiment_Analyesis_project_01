# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi161995/Sentiment_Analyesis_project_01/blob/main/src/Notebooks/Data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/sentiment-cleaned-datasetskazanovasentiment140/sentiment140_cleaned.csv')
df.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
#
#                                         cleaned_text
# 0  switchfoot httptwitpiccom2y1zl awww thats bumm...
# 1  upset cant update facebook texting might cry r...
# ...

# %%
df2=df[['target','cleaned_text']]

# %%
df2
# Out:
#          target                                       cleaned_text
# 0             0  switchfoot httptwitpiccom2y1zl awww thats bumm...
# 1             0  upset cant update facebook texting might cry r...
# 2             0  kenichan dived many times ball managed save 50...
# 3             0                   whole body feels itchy like fire
# 4             0           nationwideclass behaving im mad cant see
# ...         ...                                                ...
# 1599995       1                      woke school best feeling ever
# 1599996       1  thewdbcom cool hear old walt interviews â http...
# 1599997       1                    ready mojo makeover ask details
# 1599998       1  happy 38th birthday boo alll time tupac amaru ...
# 1599999       1  happy charitytuesday thenspcc sparkscharity sp...
#
# [1600000 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# target            0
# cleaned_text    322
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.describe(include='object')
# Out:
#        cleaned_text
# count       1599678
# unique      1554854
# top            work
# freq            555

# %%
df2.duplicated(subset=['target','cleaned_text']).sum()
# Out:
# np.int64(41341)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.sample(6)
# Out:
#          target                                       cleaned_text
# 459055        0                  guess get try act like someone im
# 757176        0                 didnt get see boyfriend last night
# 687734        0  jonathanrknight couldnt afford 2make 2my homet...
# 1588007       1               blurtit wow thanks youre like oracle
# 1521916       1  signed twitter since everyone keeps talking ca...
# 1319197       1       david_henrie followed better right bein cool

# %%
ax=sns.countplot(x='target',data=df2)
for bar in ax.containers:
    ax.bar_label(bar)
